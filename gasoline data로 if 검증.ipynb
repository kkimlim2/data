# %% [markdown]
# ## 가솔린 데이터를 이용해서 if는 어떻게 작용하는지 한번 봅시다

# %%
import outliers_detect as od

# %%
import datetime

# %%
dir(od)
# Out:
# ['ABOD',
#  'IsolationForest',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abod_outliers',
#  'if_outliers',
#  'np',
#  'pd',
#  'plt',
#  'sns']

# %%
PATH="C:\\Users\\user\\Desktop\\data\\"
df=od.pd.read_csv(PATH+"gasoline and diesel retail price.csv")

# %%
display(df)
# Out:
#             Date     A1     A2     A3     R1     R2     R3     M1     M2  \
# 0     01/02/1995  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159
# 1     01/09/1995  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164
# 2     01/16/1995  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155
# 3     01/23/1995  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165
# 4     01/30/1995  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1356  12/28/2020  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482
# 1357  01/04/2021  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484
# 1358  01/11/2021  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550
# 1359  01/18/2021  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601
# 1360  01/25/2021  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615
#
#          M3     P1     P2     P3     D1
# 0     1.298  1.272  1.250  1.386  1.104
# ...

# %%
df.dtypes
# Out:
# Date     object
# A1      float64
# A2      float64
# A3      float64
# R1      float64
# R2      float64
# R3      float64
# M1      float64
# M2      float64
# M3      float64
# P1      float64
# P2      float64
# P3      float64
# D1      float64
# dtype: object

# %%
df.Date=od.pd.to_datetime(df.Date)

# %%
display(df)
# Out:
#            Date     A1     A2     A3     R1     R2     R3     M1     M2  \
# 0    1995-01-02  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159
# 1    1995-01-09  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164
# 2    1995-01-16  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155
# 3    1995-01-23  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165
# 4    1995-01-30  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1356 2020-12-28  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482
# 1357 2021-01-04  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484
# 1358 2021-01-11  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550
# 1359 2021-01-18  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601
# 1360 2021-01-25  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615
#
#          M3     P1     P2     P3     D1
# 0     1.298  1.272  1.250  1.386  1.104
# ...

# %%
df.dtypes
# Out:
# Date    datetime64[ns]
# A1             float64
# A2             float64
# A3             float64
# R1             float64
# R2             float64
# R3             float64
# M1             float64
# M2             float64
# M3             float64
# P1             float64
# P2             float64
# P3             float64
# D1             float64
# dtype: object

# %%
fig=od.plt.figure(figsize=(30,10))
for i,col in enumerate(df.columns):
    if i==0:pass
    else: 
        od.plt.plot(df.Date,df[col],label=col)
        od.plt.legend()
od.plt.show()

# %%
x=od.if_outliers()

# %%
y=x.if_index(df)

# %%
print(y)
# Out:
# [30, 31, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 178, 181, 182, 183, 184, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 264, 265, 266, 267, 284, 285, 286, 287, 288, 297, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 353, 354, 363, 364, 365, 377, 378, 413, 414, 415, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 450, 451, 452, 453, 454, 455, 456, 457, 458, 472, 473, 474, 475, 476, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 489, 490, 491, 493, 494, 495, 496, 498, 500, 501, 502, 503, 504, 505, 506, 507, 516, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 531, 557, 644, 645, 646, 647, 648, 649, 654, 671, 672, 673, 674, 678, 679, 685, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705,
# ...

# %%
z=x.if_score(df)

# %%
df['score']=z

# %%
display(df.head())
# Out:
#         Date     A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# 0 1995-01-02  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1 1995-01-09  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 2 1995-01-16  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 3 1995-01-23  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 4 1995-01-30  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
#
#       P1     P2     P3     D1     score
# 0  1.272  1.250  1.386  1.104 -0.487183
# 1  1.279  1.256  1.387  1.102 -0.486376
# 2  1.271  1.249  1.385  1.100 -0.488284
# 3  1.277  1.256  1.378  1.095 -0.482177
# 4  1.275  1.255  1.370  1.090 -0.482954

# %%
fig=od.plt.figure(figsize=(30,10))
for i,col in enumerate(df.columns):
    if i==0 or i==14:pass
    else: 
        od.plt.plot(df.Date,df[col],label=col)
        od.plt.legend()
od.plt.axvline(x=y)
od.plt.scatter(df.loc[df['score']<-0.5,['Date']],df.loc[df['score']<-0.5,['score']])
od.plt.show()

# %%
fig=od.plt.figure(figsize=(30,10))
for i,col in enumerate(df.columns):
    if i==0 or i==14 or i==15:pass
    else: 
        od.plt.plot(df.Date,df[col],label=col)
        od.plt.legend()
od.plt.axvline(x=df.loc[df['y']==-1,['Date']])
od.plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-0f50d5ac149a> in <module>
#       5         od.plt.plot(df.Date,df[col],label=col)
#       6         od.plt.legend()
# ----> 7 od.plt.axvline(x=df.loc[df['y']==-1,['Date']])
#       8 od.plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2471 @_copy_docstring_and_deprecators(Axes.axvline)
#    2472 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2473     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2474
#    2475
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     915         trans = self.get_xaxis_transform(which='grid')
#     916         l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
# --> 917         self.add_line(l)
# ...

# %%
del kk

# %%
yy=od.np.zeros(df.shape[0])
for value in y:
    yy[value]==-1
df['y']=yy

# %%
display(df)
# Out:
#            Date     A1     A2     A3     R1     R2     R3     M1     M2  \
# 0    1995-01-02  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159
# 1    1995-01-09  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164
# 2    1995-01-16  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155
# 3    1995-01-23  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165
# 4    1995-01-30  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1356 2020-12-28  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482
# 1357 2021-01-04  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484
# 1358 2021-01-11  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550
# 1359 2021-01-18  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601
# 1360 2021-01-25  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615
#
#          M3     P1     P2     P3     D1     score    y
# ...
